# %% [markdown]
# Comment in python "# "

# %%
print("Hello #World")
# print("Hello world")
# Out:
# Hello #World

# %%
print("Hello World"#)
# Out:
#   Cell In[2], line 1
#     print("Hello World"#)
#                          ^
# SyntaxError: incomplete input
