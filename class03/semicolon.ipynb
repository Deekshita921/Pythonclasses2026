# %% [markdown]
# Method 1

# %%
num1 = 100
num2 = 200
sum_of_numbers = num1 + num2
print("Sum of numbers: ", sum_of_numbers)
# Out:
# Sum of numbers:  300

# %% [markdown]
# Method 2: Using semicolon (which is statement completion operator)

# %%
num1 = 100; num2 = 200; sum_of_numbers = num1 + num2; print("Sum of numbers: ", sum_of_numbers)
# Out:
# Sum of numbers:  300
