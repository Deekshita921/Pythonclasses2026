# %% [markdown]
# Print Function

# %%
print(1,2,3, "are", "numbers", end="\t", sep=";")
print(4,5,6)
# Out:
# 1;2;3;are;numbers	4 5 6

# %%
#b overwrites the previous character
print("He\bi")
print("First\bSecond")
print("12\b34")
# Out:
# Hi
# FirsSecond
# 134

# %%
print("First \bSecond")
# Out:
# FirstSecond

# %%
print("\bfirst")
# Out:
# first

# %%
print("He\ri")
print("12\r34")
print("first\rsecond")
print("abcdef\r1234")
print("12345\rDOG")
# Out:
# ie
# 34
# second
# 1234ef
# DOG45

# %%
print("\u20A9",200)
# Out:
# ₩ 200
